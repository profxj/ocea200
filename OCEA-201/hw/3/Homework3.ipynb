# %% [markdown]
# # OCEA 201 - Homework 3

# %%
from importlib import reload

from matplotlib import pyplot as plt
import seaborn as sns

import RY_midocn

# %%
sns.set_theme()
sns.set_style('whitegrid')
sns.set_context('notebook')

# %%
def contour_plot(field, title=None, cmap='jet', nlevels=8, clabel=True):
    fig = plt.figure(figsize=(10,10))
    cm = plt.get_cmap(cmap)
    ax = plt.gca()

    CS = ax.contour(field, levels=nlevels, cmap=cm)

    if clabel:
        ax.clabel(CS, inline=True, fontsize=12)
    if title is not None:
        ax.set_title(title, fontsize=18.)

    ax.set_aspect('equal', 'datalim')

# %% [markdown]
# # Steady-state solution of the mid-ocean gyre

# %% [markdown]
# ## Run the code for the default of $W_0 = 10^{-7} \, \rm m/s$

# %%
reload(RY_midocn)
x, y, r, we, psib, psi1, psi2, q2hat, q2 = RY_midocn.run_midocn(ncell=401)

# %% [markdown]
# ## Plot

# %% [markdown]
# ### $w_E$

# %%
fig = plt.figure(figsize=(10,10))
cm = plt.get_cmap('jet')

img = plt.contourf(we, cmap=cm, levels=20)
#
cb = plt.colorbar(img, pad=0.)
clbl=r'$w_E$ (m/s)'
cb.set_label(clbl, fontsize=20.)
cb.ax.tick_params(labelsize=17)
#
plt.axes().set_aspect('equal', 'datalim')
# Out:
# /home/xavier/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ### $\psi_B$

# %%
contour_plot(psib, title=r'$\psi_B$')

# %% [markdown]
# ## $\psi_1$

# %%
contour_plot(psi1, title=r'$\psi_1$')

# %% [markdown]
# ### $\psi_2$

# %%
contour_plot(psi2, title=r'$\psi_2$')
# Out:
# /home/xavier/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: No contour levels were found within the data range.

# %%
contour_plot(q2hat, title=r'$\hat q_2$', clabel=False)

# %%
contour_plot(q2, title=r'$q_2$', clabel=False)
